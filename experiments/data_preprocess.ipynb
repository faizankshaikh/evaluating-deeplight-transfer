# %% [markdown]
# <a href="https://colab.research.google.com/github/faizankshaikh/evaluating-deeplight-transfer/blob/master/experiments/data_preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # write table of contents and explain

# %%
#@title Connect drive to load dataset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Install data preprocessing library

# !git clone https://github.com/athms/evaluating-deeplight-transfer.git

# %cd evaluating-deeplight-transfer/

# !pip install -q poetry
# Out:
# Cloning into 'evaluating-deeplight-transfer'...
# remote: Enumerating objects: 526, done.
# remote: Total 526 (delta 0), reused 0 (delta 0), pack-reused 526
# Receiving objects: 100% (526/526), 12.07 MiB | 16.09 MiB/s, done.
# Resolving deltas: 100% (304/304), done.
# /content/evaluating-deeplight-transfer
#      |████████████████████████████████| 175 kB 9.8 MB/s
#      |████████████████████████████████| 91 kB 10.4 MB/s
#      |████████████████████████████████| 425 kB 19.8 MB/s
#      |████████████████████████████████| 54 kB 2.9 MB/s
#      |████████████████████████████████| 8.8 MB 48.9 MB/s
#      |████████████████████████████████| 40 kB 6.3 MB/s
#      |████████████████████████████████| 58 kB 6.1 MB/s
#      |████████████████████████████████| 58 kB 6.1 MB/s
#      |████████████████████████████████| 48 kB 4.7 MB/s
#      |████████████████████████████████| 4.0 MB 37.5 MB/s
#      |████████████████████████████████| 461 kB 45.9 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.7 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 1.7.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
#@title Install data preprocessing library (contd)

#edit TOML file with TF as 1.15.3

# %%writefile /content/evaluating-deeplight-transfer/pyproject.toml

[tool.poetry]
name = "evaluating-deeplight-transfer"
version = "0.1.0"
description = "Transfer learning with DeepLight"
authors = ["Armin W. Thomas <athms@stanford.edu>"]

[tool.poetry.dependencies]
python = ">=3.6.1,<4.0"
boto3 = "1.12.34"
botocore = "1.15.39"
einops = "0.3.2"
Keras = "2.2.4"
matplotlib = "3.3.4"
nilearn = "0.7.0"
numpy = "1.19.5"
tensorflow-gpu = "1.15.3"
tqdm = "4.60.0"
pandas = "1.1.5"
innvestigate = "1.0.8"
h5py = "2.10.0"

[tool.poetry.dev-dependencies]

[build-system]
requires = ["poetry-core>=1.0.0"]
build-backend = "poetry.core.masonry.api"
# Out:
# Overwriting /content/evaluating-deeplight-transfer/pyproject.toml

# %%
#@title Install data preprocessing library (contd)

# !poetry update -q > log.txt

# %%
#@title Install data preprocessing library (contd)

# %cd src/
# !poetry run pip3 install -e .
# Out:
# /content/evaluating-deeplight-transfer/src
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/evaluating-deeplight-transfer/src
#   Preparing metadata (setup.py) ... done
# Installing collected packages: deeplight
#   Running setup.py develop for deeplight
# Successfully installed deeplight-0.1.0

# %%
#@title Create AWS config

# !mkdir ~/.aws

# %%
#@title Create AWS config (contd)

# %%writefile ~/.aws/config

[profile hcp]
region=eu-central-1
# Out:
# Writing /root/.aws/config

# %%
#@title Get AWS credentials

from getpass import getpass

print('Input AWS access key ID:')
aws_access_key_id = getpass()
print('Input AWS secret access key:')
aws_secret_access_key = getpass()
# Out:
# Input AWS access key ID:
# ··········
# Input AWS secret access key:
# ··········

# %%
#@title Download data and preprocess

# %cd ../scripts/
# Out:
# /content/evaluating-deeplight-transfer/scripts

# %%
#@title Download data and preprocess (contd)

# edit download to keep task "WM" and run 'LR'
# merge download and preprocess scripts

# %%writefile /content/evaluating-deeplight-transfer/scripts/download_preprocess.py

#!/usr/bin/python
import os
import argparse
import numpy as np
import tensorflow as tf
import hcprep
import deeplight
from glob import glob


def main():

  np.random.seed(13089)

  ap = argparse.ArgumentParser()
  ap.add_argument(
    "--ACCESS-KEY",
    required=True,
    help="AWS S3 access key"
  )
  ap.add_argument(
    "--SECRET-KEY",
    required=True,
    help="AWS S3 secret key"
  )
  ap.add_argument(
    "--path",
    required=False,
    default='../data/',
    help="path to store data (default: ../data/)"
  )
  ap.add_argument(
    "-n",
    required=False,
    default=3,
    help="number of subjects to download per HCP task (1-500) (default: 3)"
  )
  ap.add_argument(
    "-c",
    required=False,
    default=0,
    help="continue download from which subject (default: 0)"
  )
  
  args = ap.parse_args()
  ACCESS_KEY = str(args.ACCESS_KEY)
  SECRET_KEY = str(args.SECRET_KEY)
  n = int(args.n)
  c = int(args.c)
  path = str(args.path)
  hcprep.paths.make_sure_path_exists(path)

  hcp_info = hcprep.info.basics()    

  # update number as per previous download    
  n=n+c

  print(
    'Download and preprocess data of {} subjects to {}'.format(
      n, path
    )
  )
  
  task_id=6
  task='WM'
  for subject_id, subject in enumerate(hcp_info.subjects[task][c:n]):
    print('\n\nWorking on subject {} of {}'.format(subject_id+1+c, n))
    run_id=0
    run='LR'
    #  for run_id, run in enumerate(hcp_info.runs):
    hcprep.download.download_subject_data(
        ACCESS_KEY=ACCESS_KEY,
        SECRET_KEY=SECRET_KEY,
        subject=subject,
        task=task,
        run=run,
        output_path=path
    )

    print('Download done!')

    filechecks = [
        os.path.isfile(
        hcprep.paths.path_bids_func_mni(
            subject=subject,
            task=task,
            run=run,
            path=path
        )
        ),
        os.path.isfile( 
        hcprep.paths.path_bids_func_mask_mni(
            subject=subject,
            task=task,
            run=run,
            path=path
        )
        ),
        os.path.isfile(
        hcprep.paths.path_bids_EV(
            subject=subject,
            task=task,
            run=run,
            path=path
        )
        )
    ]
    if not np.all(filechecks):
        print(
        'Skipping subject {} task {} run {}, because BIDS data not fully present.'.format(
            subject, task, run
        )
        )
    else:
        subject_data = hcprep.data.load_subject_data(
        task=task,
        subject=subject,
        runs=[run],
        path=path,
        t_r=hcp_info.t_r
        )
        
        func_imgs, states, trs = hcprep.preprocess.preprocess_subject_data(
        subject_data=subject_data,
        runs=[run],
        high_pass=1./128.,
        smoothing_fwhm=3
        )

        tf_record_options = tf.io.TFRecordOptions(
            compression_type="GZIP"
        )


        tfr_writers = [
        tf.io.TFRecordWriter(
            hcprep.paths.path_bids_tfr(
            subject=subject,
            task=task,
            run=run,
            path=path
            ),
            options=tf_record_options
        )
        ]
        
        deeplight.data.io.write_func_to_tfr(
        tfr_writers=tfr_writers,
        func_data=func_imgs.get_fdata(),
        states=states,
        trs=trs,
        subject_id=subject_id,
        task_id=task_id,
        run_id=run_id,
        n_onehot=hcp_info.n_states_total, # total number of cognitive states across tasks (for one-hot encoding)
        onehot_task_idx=hcp_info.onehot_idx_per_task[task], # indices of current task in onehot encoding
        randomize_volumes=True
        )
            
        [w.close() for w in tfr_writers]

        print('Preprocessing done! Deleting extra files')

        files_to_remove = glob('../data/*/*/*.txt') + glob('../data/*/*/*.gz') + glob('../data/*/*/*.csv')
        for f in files_to_remove:
            os.remove(f)
    

if __name__ == '__main__':
  
  main()
# Out:
# Writing /content/evaluating-deeplight-transfer/scripts/download_preprocess.py

# %%
#@title Download data and preprocess (contd)

# %%time
# !poetry run python download_preprocess.py -n 20 --ACCESS-KEY $aws_access_key_id --SECRET-KEY $aws_secret_access_key
# Out:
# Using TensorFlow backend.
# Download and preprocess data of 20 subjects to ../data/
#
#
# Working on subject 1 of 20
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/100307/MNINonLinear/T1w.nii.gz  to  ../data/sub-100307/anat/sub-100307_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/100307/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-100307/func/sub-100307_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# tcmalloc: large alloc 1462263808 bytes == 0x66ca000 @  0x7f2cdd6c31e7 0x4a3940 0x59b5e2 0x59ebc3 0x594a96 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x4bcb19 0x59c019 0x594d69 0x594f8e 0x595509 0x7f2cdb29286c 0x7f2cdb295a93 0x7f2cdb2960bc 0x7f2cdb296cbb 0x7f2cdb29707b 0x7f2cdb338761 0x593835
# tcmalloc: large alloc 1462263808 bytes == 0x5d950000 @  0x7f2cdd6c31e7 0x4a3940 0x5b438c 0x5d0ccd 0x59aeca 0x515655 0x549576 0x4bcb19 0x59c019 0x594d69 0x594fcf 0x59526e 0x444f5f 0x44509e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x4bcb19 0x59c019
# tcmalloc: large alloc 1462263808 bytes == 0x66ca000 @  0x7f2cdd6c31e7 0x4a3940 0x59b5e2 0x59ebc3 0x594a96 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x4bcb19 0x59c019 0x594d69 0x594f8e 0x595509 0x7f2cdb29286c 0x7f2cdb295a93 0x7f2cdb2960bc 0x7f2cdb296cbb 0x7f2cdb29707b 0x7f2cdb338761 0x593835
# tcmalloc: large alloc 2252963840 bytes == 0x66ca000 @  0x7f2cdd6c31e7 0x7f2cdb24346e 0x7f2cdb293c7b 0x7f2cdb293d97 0x7f2cdb293fe9 0x7f2cdb296d7d 0x7f2cdb29707b 0x7f2cdb338761 0x593835 0x548c51 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x511e2c 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f2cdd2c0c87 0x5b621a
# tcmalloc: large alloc 2252963840 bytes == 0x17c22e000 @  0x7f2cdd6c31e7 0x7f2cdb24346e 0x7f2cdb293c7b 0x7f2cdb293d97 0x7f2cdb28d4a5 0x7f2cdb338a2d 0x593784 0x548c51 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f2cdd2c0c87 0x5b621a
# Preprocessing done! Deleting extra files
#
#
# Working on subject 2 of 20
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/100408/MNINonLinear/T1w.nii.gz  to  ../data/sub-100408/anat/sub-100408_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/100408/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-100408/func/sub-100408_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# tcmalloc: large alloc 2252963840 bytes == 0x17c3c0000 @  0x7f2cdd6c31e7 0x7f2cdb24346e 0x7f2cdb293c7b 0x7f2cdb293d97 0x7f2cdb293fe9 0x7f2cdb296d7d 0x7f2cdb29707b 0x7f2cdb338761 0x593835 0x548c51 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x511e2c 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f2cdd2c0c87 0x5b621a
# tcmalloc: large alloc 2252963840 bytes == 0x66ca000 @  0x7f2cdd6c31e7 0x7f2cdb24346e 0x7f2cdb293c7b 0x7f2cdb293d97 0x7f2cdb28d4a5 0x7f2cdb338a2d 0x593784 0x548c51 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x593dd7 0x5118f8 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f2cdd2c0c87 0x5b621a
# Preprocessing done! Deleting extra files
#
#
# Working on subject 3 of 20
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/101006/MNINonLinear/T1w.nii.gz  to  ../data/sub-101006/anat/sub-101006_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/101006/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-101006/func/sub-101006_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 4 of 20
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/101107/MNINonLinear/T1w.nii.gz  to  ../data/sub-101107/anat/sub-101107_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/101107/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-101107/func/sub-101107_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 5 of 20
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/101309/MNINonLinear/T1w.nii.gz  to  ../data/sub-101309/anat/sub-101309_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/101309/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-101309/func/sub-101309_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 6 of 20
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/101410/MNINonLinear/T1w.nii.gz  to  ../data/sub-101410/anat/sub-101410_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/101410/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-101410/func/sub-101410_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 7 of 20
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/101915/MNINonLinear/T1w.nii.gz  to  ../data/sub-101915/anat/sub-101915_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/101915/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-101915/func/sub-101915_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 8 of 20
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/102008/MNINonLinear/T1w.nii.gz  to  ../data/sub-102008/anat/sub-102008_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/102008/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-102008/func/sub-102008_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 9 of 20
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/102311/MNINonLinear/T1w.nii.gz  to  ../data/sub-102311/anat/sub-102311_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/102311/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-102311/func/sub-102311_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 10 of 20
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/102816/MNINonLinear/T1w.nii.gz  to  ../data/sub-102816/anat/sub-102816_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/102816/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-102816/func/sub-102816_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 11 of 20
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/103111/MNINonLinear/T1w.nii.gz  to  ../data/sub-103111/anat/sub-103111_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/103111/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-103111/func/sub-103111_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 12 of 20
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/103414/MNINonLinear/T1w.nii.gz  to  ../data/sub-103414/anat/sub-103414_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/103414/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-103414/func/sub-103414_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 13 of 20
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/103515/MNINonLinear/T1w.nii.gz  to  ../data/sub-103515/anat/sub-103515_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/103515/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-103515/func/sub-103515_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 14 of 20
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/103818/MNINonLinear/T1w.nii.gz  to  ../data/sub-103818/anat/sub-103818_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/103818/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-103818/func/sub-103818_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 15 of 20
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/104820/MNINonLinear/T1w.nii.gz  to  ../data/sub-104820/anat/sub-104820_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_0bk_nlr.txt
# ...
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/104820/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-104820/func/sub-104820_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 16 of 20
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/105014/MNINonLinear/T1w.nii.gz  to  ../data/sub-105014/anat/sub-105014_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/105014/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-105014/func/sub-105014_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 17 of 20
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/105115/MNINonLinear/T1w.nii.gz  to  ../data/sub-105115/anat/sub-105115_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/105115/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-105115/func/sub-105115_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 18 of 20
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/105216/MNINonLinear/T1w.nii.gz  to  ../data/sub-105216/anat/sub-105216_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/105216/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-105216/func/sub-105216_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 19 of 20
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/106016/MNINonLinear/T1w.nii.gz  to  ../data/sub-106016/anat/sub-106016_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/106016/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-106016/func/sub-106016_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
#
#
# Working on subject 20 of 20
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/tfMRI_WM_LR.nii.gz  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_bold.nii.gz
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/brainmask_fs.2.nii.gz  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-preproc_brain_mask.nii.gz
# downloading HCP/106319/MNINonLinear/T1w.nii.gz  to  ../data/sub-106319/anat/sub-106319_space-MNI152NLin6Asym_res-2_desc-preproc_T1w.nii.gz
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_body.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_body.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_faces.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_faces.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_places.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_places.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_tools.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_tools.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_body.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_body.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_faces.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_faces.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_places.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_places.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_tools.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_tools.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_cor.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_cor.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_err.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_err.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/0bk_nlr.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_0bk_nlr.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_cor.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_cor.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_err.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_err.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/2bk_nlr.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_2bk_nlr.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_cor.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_all_bk_cor.txt
# downloading HCP/106319/MNINonLinear/Results/tfMRI_WM_LR/EVs/all_bk_err.txt  to  ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_all_bk_err.txt
# creating EV summary: ../data/sub-106319/func/sub-106319_task-WM_run-LR_desc-EV_summary.csv
# Download done!
# Preprocessing done! Deleting extra files
# CPU times: user 39.4 s, sys: 5.61 s, total: 45 s
# Wall time: 1h 5min 53s

# %%
#@title Check data size

# !du -sh ../data
# Out:
# 5.1G	../data

# %%
#@title Compress data and save to drive

# %%time
# !zip data.zip ../data/*/*/*

# !mv data.zip /content/drive/MyDrive/MAID/CV/misc
# Out:
#   adding: ../data/sub-100307/func/sub-100307_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-100408/func/sub-100408_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-101006/func/sub-101006_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-101107/func/sub-101107_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-101309/func/sub-101309_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-101410/func/sub-101410_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-101915/func/sub-101915_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-102008/func/sub-102008_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-102311/func/sub-102311_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-102816/func/sub-102816_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-103111/func/sub-103111_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-103414/func/sub-103414_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-103515/func/sub-103515_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-103818/func/sub-103818_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-104820/func/sub-104820_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-105014/func/sub-105014_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-105115/func/sub-105115_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-105216/func/sub-105216_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-106016/func/sub-106016_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
#   adding: ../data/sub-106319/func/sub-106319_task-WM_run-LR_space-MNI152NLin6Asym_res-2_desc-tfr.tfrecords (deflated 0%)
# CPU times: user 2.14 s, sys: 296 ms, total: 2.43 s
# Wall time: 4min 55s
